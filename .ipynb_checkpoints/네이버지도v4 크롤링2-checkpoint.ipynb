# %%
# 1페이지만 식당 종류별 크롤링(남부터미널 범위)
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome("c:/chromedriver.exe")
driver.get("https://v4.map.naver.com")
driver.find_elements_by_css_selector("button.btn_close")[1].click()
search_box = driver.find_element_by_css_selector("input#search-input")

list = ["남부터미널역 한식 맛집","남부터미널역 일식 맛집","남부터미널역 양식 맛집","남부터미널역 중식 맛집"]
for a in list:
    search_box.send_keys(a) 
    search_button = driver.find_element_by_css_selector("button.spm")
    search_button.click()
    print("**********"+ a +"**********")
    time.sleep(2)
    
    for i in range(1):
        stores = driver.find_elements_by_css_selector("div.lsnx")
        
        for store in stores:
            name = store.find_element_by_css_selector("dt > a").text
            addr = store.find_element_by_css_selector("dd.addr").text
            cate = store.find_element_by_css_selector("dd.cate").text
            
            print(name, addr, cate ,sep ='/')
            
        time.sleep(2)
        search_box.clear()
# Out:
# **********남부터미널역 한식 맛집**********
# 백년옥/서울특별시 서초구 남부순환로 2407 지번/한식 > 두부요리
# 탐라도야지/서울특별시 서초구 서초대로50길 82 정원빌딩 지번/한식 > 돼지고기구이
# 장꼬방묵은김치찌개전문/서울특별시 서초구 효령로 364 장꼬방 지번/한식 > 찌개,전골
# 봉산옥 서초동본점/서울특별시 서초구 반포대로8길 5-6 지번/음식점 > 한식
# 해담채 남부터미널점/서울특별시 서초구 서초중앙로5길 10-8 쁘띠오피스텔 지번/한식 > 한정식
# 감격시대/서울특별시 서초구 서초대로50길 104 코랜드빌딩 지번/한식 > 육류,고기요리
# 서초면옥 서초본점/서울특별시 서초구 반포대로28길 46 지번/한식 > 냉면
# 거북곱창/서울특별시 서초구 서초대로50길 94 세림빌딩 지번/한식 > 곱창,막창,양
# 크래버대게나라 서초점/서울특별시 서초구 반포대로 68 지번/해물,생선요리 > 게요리
# 3대삼계장인/서울특별시 서초구 반포대로28길 56-3 1층 지번/한식 > 백숙,삼계탕
# **********남부터미널역 일식 맛집**********
# 믿을신/서울특별시 서초구 서초중앙로 105 1층 지번/일식 > 돈가스
# 온센 강남점/서울특별시 서초구 서초대로73길 42 리가스퀘어 1층 111호 지번/일식 > 일식당
# 스시도우/서울특별시 서초구 서초대로42길 66 1층 지번/일식 > 초밥,롤
# 뱅스시/서울특별시 서초구 반포대로10길 35 상가동 지1층 104호 지번/일식 > 초밥,롤
# 고래/서울특별시 서초구 반포대로4길 9 서일빌딩 1층 지번/술집 > 이자카야
# 그림나베/서울특별시 서초구 서초중앙로 42 블루핀타워 112호 113호 지번/일식 > 샤브샤브
# 스시마카세 남부터미널점/서울특별시 서초구 서초중앙로 42 블루핀타워 지번/일식 > 초밥,롤
# 스시환/서울특별시 서초구 서초중앙로 38 정원빌딩 지번/일식 > 일식당
# 스시사랑/서울특별시 서초구 반포대로26길 10 진흥펠리체 1층 지번/일식 > 일식당
# 유다교대점/서울특별시 서초구 반포대로20길 57 지번/술집 > 이자카야
# **********남부터미널역 양식 맛집**********
# 오프레/서울특별시 서초구 반포대로4길 12 지번/음식점 > 프랑스음식
# 길버트버거앤프라이즈 서초점/서울특별시 서초구 서초대로42길 96 금강빌딩 지번/양식 > 햄버거
# 매드포갈릭 예술의전당점/서울특별시 서초구 반포대로 22 서초평화빌딩 지하 1층 지번/양식 > 이탈리아음식
# 요요마의키친/서울특별시 서초구 반포대로 20 정주빌딩 1층 지번/음식점 > 이탈리아음식
# 라칼라스/서울특별시 서초구 반포대로 8 삼흥빌딩 1층 지번/음식점 > 이탈리아음식
# 비노인빌라 Vino in Villa/서울특별시 서초구 남부순환로319길 14 가남빌딩 지번/음식점 > 이탈리아음식
# 미즈컨테이너 강남 웨스트/서울특별시 서초구 서초대로73길 9 타임빌딩 1층 지번/양식 > 이탈리아음식
# GBELLINI/서울특별시 서초구 남부순환로 2406 예술의전당 비타민스테이션 B1 지번/음식점 > 이탈리아음식
# 플람스 비스트로/서울특별시 서초구 남부순환로317길 41 1층 지번/음식점 > 프랑스음식
# 스모크벙커/서울특별시 서초구 반포대로28길 42 지하1층 지번/음식점 > 스테이크,립
# **********남부터미널역 중식 맛집**********
# 하오차이/서울특별시 서초구 효령로 260 지번/중식 > 중식당
# 리밍/서울특별시 서초구 반포대로22길 100 삼덕빌딩 지번/중식 > 중식당
# 리향/서울특별시 서초구 반포대로28길 15 아카디아빌딩 지번/중식 > 중식당
# 만리성/서울특별시 서초구 서초대로42길 66 지번/중식 > 중식당
# 선궁/서울특별시 서초구 반포대로 22 서초평화빌딩 지번/중식 > 중식당
# 송쉐프 르 쁘띠/서울특별시 서초구 반포대로24길 95 지번/중식 > 중식당
# 일억조24시/서울특별시 서초구 사임당로 31 궁형빌딩 지번/중식 > 중식당
# 한성양꼬치 교대2호점/서울특별시 서초구 서초대로50길 63 지번/중식 > 양꼬치
# 만다린/서울특별시 서초구 남부순환로335길 37 지번/중식 > 중식당
# 매화/서울특별시 서초구 남부순환로339길 53 지번/중식 > 중식당

# %%
# 5페이지까지 식당 종류별 크롤링(남부터미널 범위)
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome("c:/chromedriver.exe")
driver.get("https://v4.map.naver.com")
driver.find_elements_by_css_selector("button.btn_close")[1].click()
search_box = driver.find_element_by_css_selector("input#search-input")

list = ["남부터미널 한식 맛집","남부터미널 양식 맛집","남부터미널 일식 맛집","남부터미널 중식 맛집"]
for a in list:
    search_box.send_keys(a) 
    search_button = driver.find_element_by_css_selector("button.spm")
    search_button.click()
    print("**********"+ a +"**********")
    time.sleep(2)
    
    for i in range(2,6):
        stores = driver.find_elements_by_css_selector("div.lsnx")
        
        for store in stores:
            name = store.find_element_by_css_selector("dt > a").text
            addr = store.find_element_by_css_selector("dd.addr").text
            cate = store.find_element_by_css_selector("dd.cate").text
            
            print(name, addr, cate ,sep ='/')
        
        search_button = driver.find_element_by_css_selector(f"div.paginate  > a:nth-child({i+1})")
        search_button.click()
        time.sleep(2)
        search_box.clear()
# Out:
# **********남부터미널 한식 맛집**********
# 백년옥/서울특별시 서초구 남부순환로 2407 지번/한식 > 두부요리
# 임병주산동손칼국수/서울특별시 서초구 강남대로37길 63 지번/한식 > 칼국수,만두
# 봉산옥 서초동본점/서울특별시 서초구 반포대로8길 5-6 지번/음식점 > 한식
# 해담채 남부터미널점/서울특별시 서초구 서초중앙로5길 10-8 쁘띠오피스텔 지번/한식 > 한정식
# 크래버대게나라 서초점/서울특별시 서초구 반포대로 68 지번/해물,생선요리 > 게요리
# 만강홍 교대본점/서울특별시 서초구 서초중앙로22길 46 지번/중식 > 중식당
# 만리향/서울특별시 서초구 서초중앙로2길 37 지번/중식 > 중식당
# 샤오짠 서초점/서울특별시 서초구 반포대로21길 27 화원그랑빌 아파트상가 1층 108호 지번/중식 > 중식당
# 칸지고고 서초본점/서울특별시 서초구 서초대로53길 15 정원빌딩 지번/중식 > 중식당
# 옛날손짜장/서울특별시 서초구 효령로 304 국제전자센터 지번/중식 > 중식당
# 인생짬뽕 서초점/서울특별시 서초구 반포대로14길 71 1층 지번/중식 > 중식당
# 마오/서울특별시 서초구 명달로 93 지번/중식 > 중식당
# 창라이 서초반포점/서울특별시 서초구 서초중앙로 188 지번/중식 > 중식당
# 화라/서울특별시 서초구 강남대로37길 51 지번/중식 > 중식당
# 현경 교대점/서울특별시 서초구 서초대로51길 20 식당 지번/중식 > 중식당
# 팬차이나 서초점/서울특별시 서초구 서초중앙로 195 경복궁 빌딩 6층 지번/중식 > 중식당
# 홍콩반점 교대역점/서울특별시 서초구 서초대로54길 32 지번/중식 > 중식당
# 명궁/서울특별시 서초구 바우뫼로7길 13 한일프라자 지번/중식 > 중식당
# 미슌/서울특별시 서초구 서초대로53길 19 1층 지번/중식 > 중식당
# 강릉교동짬뽕교대점/서울특별시 서초구 서초대로54길 24 지번/중식 > 중식당
# 짱수양꼬치 양재점/서울특별시 서초구 서운로6길 26 지번/중식 > 양꼬치
# 열빈 본점/서울특별시 서초구 사임당로10길 11 지번/중식 > 중식당
# 국빈반점/서울특별시 서초구 사임당로17길 20 롯데빌리지 지번/중식 > 중식당
# 도화/서울특별시 서초구 서운로6길 22 지번/중식 > 중식당
# 쿵푸훠궈/서울특별시 서초구 남부순환로347길 42-4 신화빌딩 2층 지번/중식 > 양꼬치
# 마라하오 서초점/서울특별시 서초구 서초대로51길 30 지번/중식 > 중식당
# 중식전문하이난/서울특별시 서초구 서초중앙로24길 12 지번/중식 > 중식당
# 태양 손짜장/서울특별시 서초구 명달로 106 원영빌딩 지번/중식 > 중식당

# %%
# 남부->효령로로 범위 좁히기 & 1페이지만 출력
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome("c:/chromedriver.exe")
driver.get("https://v4.map.naver.com")
driver.find_elements_by_css_selector("button.btn_close")[1].click()
search_box = driver.find_element_by_css_selector("input#search-input")

list = ["효령로 한식 맛집","효령로 양식 맛집","효령로 일식 맛집","효령로 중식 맛집"]
for a in list:
    search_box.send_keys(a) 
    search_button = driver.find_element_by_css_selector("button.spm")
    search_button.click()
    print("**********"+ a +"**********")
    time.sleep(2)
    
    for i in range(1):
        stores = driver.find_elements_by_css_selector("div.lsnx")
        
        for store in stores:
            name = store.find_element_by_css_selector("dt > a").text
            addr = store.find_element_by_css_selector("dd.addr").text
            cate = store.find_element_by_css_selector("dd.cate").text
            print(name, addr, cate ,sep ='/')
        
#         search_button = driver.find_element_by_css_selector(f"div.paginate  > a:nth-child({i+1})")     
#         search_button.click()
        time.sleep(2)
        search_box.clear()
# Out:
# **********효령로 한식 맛집**********
# 장꼬방묵은김치찌개전문/서울특별시 서초구 효령로 364 장꼬방 지번/한식 > 찌개,전골
# 찜통 남부터미널점/서울특별시 서초구 효령로 276 지번/한식 > 육류,고기요리
# 본죽 남부터미널점/서울특별시 서초구 효령로 303 부속상가 10동 101호 지번/음식점 > 죽
# 강창구찹쌀진순대 남부터미널점/서울특별시 서초구 효령로 330-1 지번/한식 > 순대,순댓국
# 강촌식당 서초점/서울특별시 서초구 효령로 316-1 1층 지번/한식 > 닭갈비
# 정순화청국장/서울특별시 서초구 효령로 362 지번/한식 > 보리밥
# 북창동순두부 서초점/서울특별시 서초구 효령로 330 해평빌딩 지번/한식 > 두부요리
# 신선설농탕 서초점/서울특별시 서초구 효령로 322 신선설농탕 지번/한식 > 곰탕,설렁탕
# 부산아지매국밥 BC카드점/서울특별시 서초구 효령로 264 지번/한식 > 국밥
# 삼계탕마을 서초점/서울특별시 서초구 효령로 316 지번/한식 > 백숙,삼계탕
# **********효령로 양식 맛집**********
# 크림앤토마토/서울특별시 서초구 효령로 304 국제전자센터 지번/음식점 > 이탈리아음식
# 롯데리아 남부터미널점/서울특별시 서초구 효령로 289 장곡빌딩 지번/양식 > 햄버거
# 파파존스 서초점/서울특별시 서초구 효령로 318 지번/음식점 > 피자
# 12바스켓/서울특별시 서초구 효령로 304 국제전자센터 국제전자센터 지하1층 14호 지번/양식 > 샌드위치
# KFC 서초동점/서울특별시 서초구 효령로 283 지번/양식 > 햄버거
# 노브랜드버거 남부터미널점/서울특별시 서초구 효령로 292 남부터미널 대합실 119호 지번/양식 > 햄버거
# Da Pitta/서울특별시 서초구 효령로 202 서초빌딩 지번/음식점 > 이탈리아음식
# 퀴즈노스 남부터미널점/서울특별시 서초구 효령로 276 1층 (서초동) 지번/음식점 > 샌드위치
# 다피타/서울특별시 서초구 효령로 202 지번/음식점 > 이탈리아음식
# 미스터피자 방배본점/서울특별시 서초구 효령로 132 지번/음식점 > 피자
# **********효령로 일식 맛집**********
# 오우치/서울특별시 서초구 효령로 266 태원빌딩 1층 지번/일식 > 일식당
# 미토요/서울특별시 서초구 효령로 279 삼경빌딩 지하1층 지번/일식 > 돈가스
# 샤브향 서초남부점/서울특별시 서초구 효령로 260 서초빌딩 지번/일식 > 샤브샤브
# 오사카동/서울특별시 서초구 효령로 289 장곡빌딩 지번/일식 > 일식당
# 스시 36.5/서울특별시 서초구 효령로 307 스시36.5 지번/일식 > 초밥,롤
# 조밥집/서울특별시 서초구 효령로 237 서초한신리빙타워 지번/일식 > 일식당
# 허수아비돈까스전문점/서울특별시 서초구 효령로 307 지번/일식 > 돈가스
# 방배왕돈까스/서울특별시 서초구 효령로 132 지번/일식 > 돈가스
# 1992길건너카츠/서울특별시 서초구 효령로 72 1층 1호 지번/일식 > 돈가스
# 오니기리와이규동/서울특별시 서초구 효령로 117 지번/일식 > 오니기리
# **********효령로 중식 맛집**********
# 하오차이/서울특별시 서초구 효령로 260 지번/중식 > 중식당
# 다리원/서울특별시 서초구 효령로 105 범창빌딩 지번/중식 > 중식당
# 산동/서울특별시 서초구 효령로 214 삼양빌딩 지번/중식 > 중식당
# 강남짬뽕/서울특별시 서초구 효령로 289 지번/중식 > 중식당
# 남부양꼬치 마라탕/서울특별시 서초구 효령로 314 지번/중식 > 중식당
# 옛날손짜장/서울특별시 서초구 효령로 304 국제전자센터 지번/중식 > 중식당
